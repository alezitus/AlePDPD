# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
b0 = np.random.rand(2)

# %%
cov = np.array([[3, 1], [1,2]])
def mp(cov, num):
    for n in range(num):
        if n == 0:
            bk = cov.dot(b0)
        else:
            bk = cov.dot(bk)
        norm = np.linalg.norm(bk)
        bknorm = bk/norm
    return bknorm

# %%
def online(a):
    global x
    global W
    global sizex
    global cov
    a = a
    Want = W
    cont = it = 0
    w1 = list()
    w2 = list()
    for n in range(sizex):
        y = (W).dot(x[n,:])
        c = (x[n,:].T)*(y)
        d = y*y*(W)
        dw = a*(c - d)
        Want = W
        W= W+dw
        dif1 = np.abs(W[0][0] - Want[0][0])
        dif2 = np.abs(W[0][1] - Want[0][1])
        if dif1 < a*1.5 and dif2 < a*1.5:
            it += 1
        else:
            it = 0
        if it == 10 :
            break
        cont = cont+1
        w1.append(W[0][0])
        w2.append(W[0][1])
    plt.figure()
    plt.title('Online Learning')
    plt.plot(w1)
    plt.plot(w2)
    print(f'Método: Online Learning\nTaxa de Aprendizagem: {a}\nNúmero de Amostras em X: {sizex}\nVetor W: {W}\nAutovetor: {mp(cov,10)}\nNúmero de iterações até convergência:{cont}')
    print()

# %%
def batch(a):
    global x
    global W
    global sizex
    global cov
    a = a
    Want = W
    cont = it = 0
    w1 = list()
    w2 = list()
    for n in range(0,sizex,10):
        z1 = list()
        z2 = list()
        z = [m for m in x[n:n+10,:]]
        for v in range (0,10):
            z1.append(z[v][0])
            z2.append(z[v][1])
        z1 = np.array(z1)
        z2 = np.array(z2)
        z1 = z1.mean()
        z2 = z2.mean()
        z = np.array([z1, z2])
        y = (W).dot(x[n,:])
        c = (x[n,:].T)*(y)
        d = y*y*(W)
        dw = a*(c - d)
        Want = W
        W= W+dw
        dif1 = np.abs(W[0][0] - Want[0][0])
        dif2 = np.abs(W[0][1] - Want[0][1])
        if dif1 < a*1.5 and dif2 < a*1.5:
            it += 1
        else:
            it = 0
        if it == 5 :
            break
        cont = cont+1
        w1.append(W[0][0])
        w2.append(W[0][1])
    plt.figure()
    plt.title('Batch Learning')
    plt.plot(w1)
    plt.plot(w2)
    print(f'Método: Batch Learning\nTaxa de Aprendizagem : {a}\nNúmero de Amostras em X: {sizex}\nVetor W: {W}\nAutovetor: {mp(cov,10)}\nNúmero de iterações até convergência:{cont}')

# %%
sizex = 1000
cov = np.array([[3, 1], [1,2]])
mean = np.zeros(2)
b0 = np.random.rand(2)
x = np.random.multivariate_normal(mean = mean, cov = cov, size =sizex)
W = np.random.rand(1,2)

# %%
online(0.001)
batch(0.001)
# Out:
# Método: Online Learning
# Taxa de Aprendizagem: 0.001
# Número de Amostras em X: 1000
# Vetor W: [[0.54360041 0.59828043]]
# Autovetor: [0.85065193 0.52572929]
# Número de iterações até convergência:59
#
# Método: Batch Learning
# Taxa de Aprendizagem : 0.001
# Número de Amostras em X: 1000
# Vetor W: [[0.54705596 0.5965983 ]]
# Autovetor: [0.85065193 0.52572929]
# Número de iterações até convergência:4

# %%
online(0.005)
batch(0.005)
# Out:
# Método: Online Learning
# Taxa de Aprendizagem: 0.005
# Número de Amostras em X: 1000
# Vetor W: [[0.77293807 0.5719073 ]]
# Autovetor: [0.85065193 0.52572929]
# Número de iterações até convergência:55
#
# Método: Batch Learning
# Taxa de Aprendizagem : 0.005
# Número de Amostras em X: 1000
# Vetor W: [[0.78875816 0.55367583]]
# Autovetor: [0.85065193 0.52572929]
# Número de iterações até convergência:4

# %%
online(0.01)
batch(0.01)
# Out:
# Método: Online Learning
# Taxa de Aprendizagem: 0.01
# Número de Amostras em X: 1000
# Vetor W: [[0.83342514 0.51629886]]
# Autovetor: [0.85065193 0.52572929]
# Número de iterações até convergência:12
#
# Método: Batch Learning
# Taxa de Aprendizagem : 0.01
# Número de Amostras em X: 1000
# Vetor W: [[0.86604051 0.46605534]]
# Autovetor: [0.85065193 0.52572929]
# Número de iterações até convergência:8

# %%
online(0.05)
batch(0.05)
# Out:
# Método: Online Learning
# Taxa de Aprendizagem: 0.05
# Número de Amostras em X: 1000
# Vetor W: [[0.96912852 0.25871668]]
# Autovetor: [0.85065193 0.52572929]
# Número de iterações até convergência:47
#
# Método: Batch Learning
# Taxa de Aprendizagem : 0.05
# Número de Amostras em X: 1000
# Vetor W: [[1.00435198 0.03160822]]
# Autovetor: [0.85065193 0.52572929]
# Número de iterações até convergência:8

# %%
online(0.1)
batch(0.1)
# Out:
# Método: Online Learning
# Taxa de Aprendizagem: 0.1
# Número de Amostras em X: 1000
# Vetor W: [[0.74389452 0.67378184]]
# Autovetor: [0.85065193 0.52572929]
# Número de iterações até convergência:25
#
# Método: Batch Learning
# Taxa de Aprendizagem : 0.1
# Número de Amostras em X: 1000
# Vetor W: [[1.00630016 0.13831355]]
# Autovetor: [0.85065193 0.52572929]
# Número de iterações até convergência:8

# %%
def online1(a):
    global x
    global W
    global sizex
    global cov
    a = a
    Want = W
    cont = it = 0
    w1 = list()
    w2 = list()
    for n in range(sizex):
        y = (W).dot(x[n,:])
        c = (x[n,:].T)*(y)
        d = y*y*(W)
        dw = a*(c - d)
        Want = W
        W= W+dw
        dif1 = np.abs(W[0][0] - Want[0][0])
        dif2 = np.abs(W[0][1] - Want[0][1])
        if dif1 < a*1.5 and dif2 < a*1.5:
            it += 1
        else:
            it = 0
        if it == 10 :
            break
        cont = cont+1
        w1.append(W[0][0])
        w2.append(W[0][1])
    plt.figure()
    plt.title('Online Learning')
    plt.plot(w1)
    plt.plot(w2)
    print(f'Método: Online Learning\nTaxa de Aprendizagem: {a}\nNúmero de Amostras em X: {sizex}\nVetor W: {W}\nAutovetor: {mp(cov,10)}\nNúmero de iterações até convergência:{cont}')
    print()
